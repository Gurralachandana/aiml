# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.cluster import KMeans

# %%
Univ = pd.read_csv("Universities1.csv")
Univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
Univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
# Univ        25 non-null object
# SAT         25 non-null int64
# Top10       25 non-null int64
# Accept      25 non-null int64
# SFRatio     25 non-null int64
# Expenses    25 non-null int64
# GradRate    25 non-null int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
Univ.corr()
# Out:
#                SAT     Top10    Accept   SFRatio  Expenses  GradRate
# SAT       1.000000  0.922522 -0.885850 -0.812552  0.778976  0.747712
# Top10     0.922522  1.000000 -0.859181 -0.643435  0.611467  0.745942
# Accept   -0.885850 -0.859181  1.000000  0.631664 -0.558439 -0.819550
# SFRatio  -0.812552 -0.643435  0.631664  1.000000 -0.781839 -0.560922
# Expenses  0.778976  0.611467 -0.558439 -0.781839  1.000000  0.393591
# GradRate  0.747712  0.745942 -0.819550 -0.560922  0.393591  1.000000

# %% [markdown]
# # Standardization of the data

# %%
Univ1 = Univ.iloc[:,1:]

# %%
Univ1
# Out:
#      SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0   1310     89      22       13     22704        94
# 1   1415    100      25        6     63575        81
# 2   1260     62      59        9     25026        72
# 3   1310     76      24       12     31510        88
# 4   1280     83      33       13     21864        90
# 5   1340     89      23       10     32162        95
# 6   1315     90      30       12     31585        95
# 7   1255     74      24       12     20126        92
# 8   1400     91      14       11     39525        97
# 9   1305     75      44        7     58691        87
# 10  1380     94      30       10     34870        91
# 11  1260     85      39       11     28052        89
# 12  1255     81      42       13     15122        94
# 13  1081     38      54       18     10185        80
# 14  1375     91      14        8     30220        95
# 15  1005     28      90       19      9066        69
# 16  1360     90      20       12     36450        93
# ...

# %%
cols = Univ1.columns

# %%
cols
# Out:
# Index(['SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %%
#Standardization function
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_Univ_df = pd.DataFrame(scaler.fit_transform(Univ1),columns = cols)
scaled_Univ_df
# Out:
#          SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0   0.410284  0.657519 -0.889867  0.070260 -0.331413  0.820303
# 1   1.399259  1.235212 -0.734657 -1.686251  2.560381 -0.644524
# 2  -0.060657 -0.760454  1.024382 -0.933460 -0.167121 -1.658634
# 3   0.410284 -0.025208 -0.786394 -0.180670  0.291649  0.144229
# 4   0.127719  0.342414 -0.320766  0.070260 -0.390846  0.369587
# 5   0.692848  0.657519 -0.838130 -0.682530  0.337780  0.932982
# 6   0.457378  0.710037 -0.475975 -0.180670  0.296955  0.932982
# 7  -0.107751 -0.130243 -0.786394 -0.180670 -0.513817  0.594945
# 8   1.257977  0.762555 -1.303758 -0.431600  0.858743  1.158339
# 9   0.363190 -0.077726  0.248335 -1.435321  2.214818  0.031550
# 10  1.069601  0.920107 -0.475975 -0.682530  0.529383  0.482266
# 11 -0.060657  0.447449 -0.010347 -0.431600  0.046981  0.256908
# 12 -0.107751  0.237379  0.144862  0.070260 -0.867871  0.820303
# 13 -1.746625 -2.020875  0.765699  1.324911 -1.217184 -0.757202
# ...

# %%
# BUild 3 clusters using KMeans cluster algorithm
from sklearn.cluster import KMeans
clusters_new = KMeans(3, random_state=0)
clusters_new.fit(scaled_Univ_df)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
# print the cluster labels
clusters_new.labels_
# Out:
# array([2, 0, 2, 2, 2, 0, 0, 2, 0, 0, 0, 2, 2, 1, 0, 1, 0, 1, 2, 2, 2, 2,
#        2, 1, 0])

# %%
set(clusters_new.labels_)
# Out:
# {0, 1, 2}

# %%
# Assign cluster to the Univ data set
Univ['clusterid_new'] = clusters_new.labels_

# %%
Univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
Univ.sort_values(by = "clusterid_new")
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 24          Yale  1375     95      19       11     43514        96
# 14     Princeton  1375     91      14        8     30220        95
# 10           MIT  1380     94      30       10     34870        91
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 16      Stanford  1360     90      20       12     36450        93
# 6           Duke  1315     90      30       12     31585        95
# 8        Harvard  1400     91      14       11     39525        97
# 1        CalTech  1415    100      25        6     63575        81
# 5      Dartmouth  1340     89      23       10     32162        95
# 23    UWisconsin  1085     40      69       15     11857        71
# 13     PennState  1081     38      54       18     10185        80
# 15        Purdue  1005     28      90       19      9066        69
# 17      TexasA&M  1075     49      67       25      8704        67
# ...

# %%
#use groupby() to find aggregated(mean) values in each cluster
Univ.iloc[:,1:].groupby("clusterid_new").mean()
# Out:
#                        SAT      Top10     Accept    SFRatio      Expenses  \
# clusterid_new
# 0              1362.777778  90.555556  24.333333   9.666667  41176.888889
# 1              1061.500000  38.750000  70.000000  19.250000   9953.000000
# 2              1262.500000  78.500000  40.083333  12.833333  22858.000000
#
#                 GradRate
# clusterid_new
# 0              92.222222
# 1              71.750000
# 2              87.583333

# %% [markdown]
# # Observations
# - Custer 1 appears to be the top rated universities cluster as the cut off score, Top 10, SFRatio parameter mean values are highest
# - Cluster 2 appears to occupy the middle level rated universities
# - Cluster 0 comes as the lower level rated universities

# %%
Univ[Univ['clusterid_new']==0]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 1        CalTech  1415    100      25        6     63575        81
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 14     Princeton  1375     91      14        8     30220        95
# 16      Stanford  1360     90      20       12     36450        93
# 24          Yale  1375     95      19       11     43514        96
#
#     clusterid_new
# 1               0
# 5               0
# 6               0
# 8               0
# 9               0
# 10              0
# 14              0
# 16              0
# 24              0

# %% [markdown]
# # Finding optimal k value using elbow plot

# %%
wcss = []
for i in range(1,20):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_Univ_df)
    wcss.append(kmeans.inertia_)
print(wcss)
plt.plot(range(1,20), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# [150.0, 64.1452839501027, 44.531761731450956, 33.654341806512235, 26.953681627883107, 23.028199078329926, 18.568917030859872, 16.30166464097455, 13.478804389760812, 10.640545447539143, 8.5680038214307, 6.941824418898122, 5.627990209789381, 4.4729501687109625, 3.5888442397910936, 2.9298229590953895, 2.2348202970652253, 1.5455086869756587, 1.1758698663599076]

# %%
#QUALITY of clusters is expected in terms of silhoute score
from sklearn.metrics import silhouette_score
score = silhouette_score(scaled_Univ_df,clusters_new.labels_, metric="euclidean")
score
# Out:
# 0.3220757437494107
